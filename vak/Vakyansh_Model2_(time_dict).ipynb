# %% [markdown]
# <a href="https://colab.research.google.com/github/ekshaks/ekshaks.github.io/blob/master/vak/Vakyansh_Model2_(time_dict).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture

# !pip install git+https://github.com/huggingface/transformers.git datasets librosa torch==1.7.0 torchaudio==0.7.0 jiwer

# %%
import torch
import torchaudio
from datasets import load_dataset, load_metric
from transformers import Wav2Vec2ForCTC, Wav2Vec2Processor
import re

test_dataset = load_dataset("common_voice", "hi", split="test")
wer = load_metric("wer")

processor = Wav2Vec2Processor.from_pretrained("Harveenchadha/vakyansh-wav2vec2-hindi-him-4200")
model = Wav2Vec2ForCTC.from_pretrained("Harveenchadha/vakyansh-wav2vec2-hindi-him-4200")
model.to("cuda")
# Out:
# /usr/local/lib/python3.7/dist-packages/torchaudio/backend/utils.py:54: UserWarning: "sox" backend is being deprecated. The default backend will be changed to "sox_io" backend in 0.8.0 and "sox" backend will be removed in 0.9.0. Please migrate to "sox_io" backend. Please refer to https://github.com/pytorch/audio/issues/903 for the detail.
#   '"sox" backend is being deprecated. '
# Downloading:   0%|          | 0.00/4.44k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.2k [00:00<?, ?B/s]
# Downloading and preparing dataset common_voice/hi (download: 20.43 MiB, generated: 286.19 KiB, post-processed: Unknown size, total: 20.71 MiB) to /root/.cache/huggingface/datasets/common_voice/hi/6.1.0/f7a9d973839b7706e9e281c19b7e512f31badf3c0fdbd21c671f3c4bf9acf3b9...
# Downloading:   0%|          | 0.00/21.4M [00:00<?, ?B/s]
# 0 examples [00:00, ? examples/s]
# 0 examples [00:00, ? examples/s]
# 0 examples [00:00, ? examples/s]
# 0 examples [00:00, ? examples/s]
# 0 examples [00:00, ? examples/s]
# Dataset common_voice downloaded and prepared to /root/.cache/huggingface/datasets/common_voice/hi/6.1.0/f7a9d973839b7706e9e281c19b7e512f31badf3c0fdbd21c671f3c4bf9acf3b9. Subsequent calls will reuse this data.
# Downloading:   0%|          | 0.00/1.95k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/213 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/730 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/181 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/85.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/360M [00:00<?, ?B/s]
# Wav2Vec2ForCTC(
#   (wav2vec2): Wav2Vec2Model(
#     (feature_extractor): Wav2Vec2FeatureExtractor(
#       (conv_layers): ModuleList(
#         (0): Wav2Vec2GroupNormConvLayer(
#           (conv): Conv1d(1, 512, kernel_size=(10,), stride=(5,), bias=False)
#           (layer_norm): GroupNorm(512, 512, eps=1e-05, affine=True)
#         )
#         (1): Wav2Vec2NoLayerNormConvLayer(
#           (conv): Conv1d(512, 512, kernel_size=(3,), stride=(2,), bias=False)
#         )
#         (2): Wav2Vec2NoLayerNormConvLayer(
#           (conv): Conv1d(512, 512, kernel_size=(3,), stride=(2,), bias=False)
#         )
#         (3): Wav2Vec2NoLayerNormConvLayer(
#           (conv): Conv1d(512, 512, kernel_size=(3,), stride=(2,), bias=False)
#         )
#         (4): Wav2Vec2NoLayerNormConvLayer(
#           (conv): Conv1d(512, 512, kernel_size=(3,), stride=(2,), bias=False)
#         )
#         (5): Wav2Vec2NoLayerNormConvLayer(
#           (conv): Conv1d(512, 512, kernel_size=(2,), stride=(2,), bias=False)
#         )
#         (6): Wav2Vec2NoLayerNormConvLayer(
#           (conv): Conv1d(512, 512, kernel_size=(2,), stride=(2,), bias=False)
#         )
#       )
#     )
#     (feature_projection): Wav2Vec2FeatureProjection(
#       (layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (projection): Linear(in_features=512, out_features=768, bias=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): Wav2Vec2Encoder(
#       (pos_conv_embed): Wav2Vec2PositionalConvEmbedding(
#         (conv): Conv1d(768, 768, kernel_size=(128,), stride=(1,), padding=(64,), groups=16)
#         (padding): Wav2Vec2SamePadLayer()
#       )
#       (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (layers): ModuleList(
#         (0): Wav2Vec2EncoderLayer(
#           (attention): Wav2Vec2Attention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): Wav2Vec2FeedForward(
#             (intermediate_dropout): Dropout(p=0.1, inplace=False)
#             (intermediate_dense): Linear(in_features=768, out_features=3072, bias=True)
#             (output_dense): Linear(in_features=3072, out_features=768, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): Wav2Vec2EncoderLayer(
#           (attention): Wav2Vec2Attention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): Wav2Vec2FeedForward(
#             (intermediate_dropout): Dropout(p=0.1, inplace=False)
#             (intermediate_dense): Linear(in_features=768, out_features=3072, bias=True)
#             (output_dense): Linear(in_features=3072, out_features=768, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (2): Wav2Vec2EncoderLayer(
#           (attention): Wav2Vec2Attention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): Wav2Vec2FeedForward(
#             (intermediate_dropout): Dropout(p=0.1, inplace=False)
#             (intermediate_dense): Linear(in_features=768, out_features=3072, bias=True)
#             (output_dense): Linear(in_features=3072, out_features=768, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (3): Wav2Vec2EncoderLayer(
#           (attention): Wav2Vec2Attention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): Wav2Vec2FeedForward(
#             (intermediate_dropout): Dropout(p=0.1, inplace=False)
#             (intermediate_dense): Linear(in_features=768, out_features=3072, bias=True)
#             (output_dense): Linear(in_features=3072, out_features=768, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (4): Wav2Vec2EncoderLayer(
#           (attention): Wav2Vec2Attention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): Wav2Vec2FeedForward(
#             (intermediate_dropout): Dropout(p=0.1, inplace=False)
#             (intermediate_dense): Linear(in_features=768, out_features=3072, bias=True)
#             (output_dense): Linear(in_features=3072, out_features=768, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (5): Wav2Vec2EncoderLayer(
#           (attention): Wav2Vec2Attention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): Wav2Vec2FeedForward(
#             (intermediate_dropout): Dropout(p=0.1, inplace=False)
#             (intermediate_dense): Linear(in_features=768, out_features=3072, bias=True)
#             (output_dense): Linear(in_features=3072, out_features=768, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (6): Wav2Vec2EncoderLayer(
#           (attention): Wav2Vec2Attention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): Wav2Vec2FeedForward(
#             (intermediate_dropout): Dropout(p=0.1, inplace=False)
#             (intermediate_dense): Linear(in_features=768, out_features=3072, bias=True)
#             (output_dense): Linear(in_features=3072, out_features=768, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (7): Wav2Vec2EncoderLayer(
#           (attention): Wav2Vec2Attention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): Wav2Vec2FeedForward(
#             (intermediate_dropout): Dropout(p=0.1, inplace=False)
#             (intermediate_dense): Linear(in_features=768, out_features=3072, bias=True)
#             (output_dense): Linear(in_features=3072, out_features=768, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (8): Wav2Vec2EncoderLayer(
#           (attention): Wav2Vec2Attention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): Wav2Vec2FeedForward(
#             (intermediate_dropout): Dropout(p=0.1, inplace=False)
#             (intermediate_dense): Linear(in_features=768, out_features=3072, bias=True)
#             (output_dense): Linear(in_features=3072, out_features=768, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (9): Wav2Vec2EncoderLayer(
#           (attention): Wav2Vec2Attention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): Wav2Vec2FeedForward(
#             (intermediate_dropout): Dropout(p=0.1, inplace=False)
#             (intermediate_dense): Linear(in_features=768, out_features=3072, bias=True)
#             (output_dense): Linear(in_features=3072, out_features=768, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (10): Wav2Vec2EncoderLayer(
#           (attention): Wav2Vec2Attention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): Wav2Vec2FeedForward(
#             (intermediate_dropout): Dropout(p=0.1, inplace=False)
#             (intermediate_dense): Linear(in_features=768, out_features=3072, bias=True)
#             (output_dense): Linear(in_features=3072, out_features=768, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (11): Wav2Vec2EncoderLayer(
#           (attention): Wav2Vec2Attention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): Wav2Vec2FeedForward(
#             (intermediate_dropout): Dropout(p=0.1, inplace=False)
#             (intermediate_dense): Linear(in_features=768, out_features=3072, bias=True)
#             (output_dense): Linear(in_features=3072, out_features=768, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (lm_head): Linear(in_features=768, out_features=67, bias=True)
# )

# %%
resampler = torchaudio.transforms.Resample(48_000, 16_000)

chars_to_ignore_regex = '[\,\?\.\!\-\;\:\"\“]'

# Preprocessing the datasets.
# We need to read the aduio files as arrays
def speech_file_to_array_fn(batch):
  batch["sentence"] = re.sub(chars_to_ignore_regex, '', batch["sentence"]).lower()
  speech_array, sampling_rate = torchaudio.load(batch["path"])
  batch["speech"] = resampler(speech_array).squeeze().numpy()
  return batch

test_dataset = test_dataset.map(speech_file_to_array_fn)

# Preprocessing the datasets.
# We need to read the aduio files as arrays
def evaluate(batch):
  inputs = processor(batch["speech"], sampling_rate=16_000, return_tensors="pt", padding=True)

  with torch.no_grad():
      logits = model(inputs.input_values.to("cuda")).logits

      pred_ids = torch.argmax(logits, dim=-1)
      batch["pred_strings"] = processor.batch_decode(pred_ids, skip_special_tokens=True)
      return batch

result = test_dataset.map(evaluate, batched=True, batch_size=8)

print("WER: {:2f}".format(100 * wer.compute(predictions=result["pred_strings"], references=result["sentence"])))
# Out:
#   0%|          | 0/127 [00:00<?, ?ex/s]
#   0%|          | 0/16 [00:00<?, ?ba/s]
# WER: 32.946636

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import librosa
import soundfile as sf
import numpy as np

# %%
counter
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-1cbe4252e8d3> in <module>()
# ----> 1 counter
#
# NameError: name 'counter' is not defined

# %%
b=[]
inputs = processor(a, sampling_rate=16_000, return_tensors="pt", padding=True)

with torch.no_grad():
    logits = model(inputs.input_values.to("cuda")).logits
    pred_ids = torch.argmax(logits, dim=-1)
    b = processor.batch_decode(pred_ids, skip_special_tokens=True)

# %%
len(a[1])
# Out:
# 36750

# %%
a=[]
for i in range (1,42):
  path='/content/drive/MyDrive/'+str(i)+'.wav'
  speech_array, sampling_rate = torchaudio.load(path)
  x =speech_array[0].numpy()
  x=librosa.resample(np.asarray(x), sampling_rate, 16_000)

  a.append(x)

# %%
processor1 = Wav2Vec2Processor.from_pretrained("Harveenchadha/vakyansh-wav2vec2-indian-english-enm-700")
model1 = Wav2Vec2ForCTC.from_pretrained("Harveenchadha/vakyansh-wav2vec2-indian-english-enm-700")
model1.to("cuda")
# Out:
# Downloading:   0%|          | 0.00/213 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/291 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/181 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/85.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.62k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/360M [00:00<?, ?B/s]
# Wav2Vec2ForCTC(
#   (wav2vec2): Wav2Vec2Model(
#     (feature_extractor): Wav2Vec2FeatureExtractor(
#       (conv_layers): ModuleList(
#         (0): Wav2Vec2GroupNormConvLayer(
#           (conv): Conv1d(1, 512, kernel_size=(10,), stride=(5,), bias=False)
#           (layer_norm): GroupNorm(512, 512, eps=1e-05, affine=True)
#         )
#         (1): Wav2Vec2NoLayerNormConvLayer(
#           (conv): Conv1d(512, 512, kernel_size=(3,), stride=(2,), bias=False)
#         )
#         (2): Wav2Vec2NoLayerNormConvLayer(
#           (conv): Conv1d(512, 512, kernel_size=(3,), stride=(2,), bias=False)
#         )
#         (3): Wav2Vec2NoLayerNormConvLayer(
#           (conv): Conv1d(512, 512, kernel_size=(3,), stride=(2,), bias=False)
#         )
#         (4): Wav2Vec2NoLayerNormConvLayer(
#           (conv): Conv1d(512, 512, kernel_size=(3,), stride=(2,), bias=False)
#         )
#         (5): Wav2Vec2NoLayerNormConvLayer(
#           (conv): Conv1d(512, 512, kernel_size=(2,), stride=(2,), bias=False)
#         )
#         (6): Wav2Vec2NoLayerNormConvLayer(
#           (conv): Conv1d(512, 512, kernel_size=(2,), stride=(2,), bias=False)
#         )
#       )
#     )
#     (feature_projection): Wav2Vec2FeatureProjection(
#       (layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       (projection): Linear(in_features=512, out_features=768, bias=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): Wav2Vec2Encoder(
#       (pos_conv_embed): Wav2Vec2PositionalConvEmbedding(
#         (conv): Conv1d(768, 768, kernel_size=(128,), stride=(1,), padding=(64,), groups=16)
#         (padding): Wav2Vec2SamePadLayer()
#       )
#       (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#       (layers): ModuleList(
#         (0): Wav2Vec2EncoderLayer(
#           (attention): Wav2Vec2Attention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): Wav2Vec2FeedForward(
#             (intermediate_dropout): Dropout(p=0.1, inplace=False)
#             (intermediate_dense): Linear(in_features=768, out_features=3072, bias=True)
#             (output_dense): Linear(in_features=3072, out_features=768, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (1): Wav2Vec2EncoderLayer(
#           (attention): Wav2Vec2Attention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): Wav2Vec2FeedForward(
#             (intermediate_dropout): Dropout(p=0.1, inplace=False)
#             (intermediate_dense): Linear(in_features=768, out_features=3072, bias=True)
#             (output_dense): Linear(in_features=3072, out_features=768, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (2): Wav2Vec2EncoderLayer(
#           (attention): Wav2Vec2Attention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): Wav2Vec2FeedForward(
#             (intermediate_dropout): Dropout(p=0.1, inplace=False)
#             (intermediate_dense): Linear(in_features=768, out_features=3072, bias=True)
#             (output_dense): Linear(in_features=3072, out_features=768, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (3): Wav2Vec2EncoderLayer(
#           (attention): Wav2Vec2Attention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): Wav2Vec2FeedForward(
#             (intermediate_dropout): Dropout(p=0.1, inplace=False)
#             (intermediate_dense): Linear(in_features=768, out_features=3072, bias=True)
#             (output_dense): Linear(in_features=3072, out_features=768, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (4): Wav2Vec2EncoderLayer(
#           (attention): Wav2Vec2Attention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): Wav2Vec2FeedForward(
#             (intermediate_dropout): Dropout(p=0.1, inplace=False)
#             (intermediate_dense): Linear(in_features=768, out_features=3072, bias=True)
#             (output_dense): Linear(in_features=3072, out_features=768, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (5): Wav2Vec2EncoderLayer(
#           (attention): Wav2Vec2Attention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): Wav2Vec2FeedForward(
#             (intermediate_dropout): Dropout(p=0.1, inplace=False)
#             (intermediate_dense): Linear(in_features=768, out_features=3072, bias=True)
#             (output_dense): Linear(in_features=3072, out_features=768, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (6): Wav2Vec2EncoderLayer(
#           (attention): Wav2Vec2Attention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): Wav2Vec2FeedForward(
#             (intermediate_dropout): Dropout(p=0.1, inplace=False)
#             (intermediate_dense): Linear(in_features=768, out_features=3072, bias=True)
#             (output_dense): Linear(in_features=3072, out_features=768, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (7): Wav2Vec2EncoderLayer(
#           (attention): Wav2Vec2Attention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): Wav2Vec2FeedForward(
#             (intermediate_dropout): Dropout(p=0.1, inplace=False)
#             (intermediate_dense): Linear(in_features=768, out_features=3072, bias=True)
#             (output_dense): Linear(in_features=3072, out_features=768, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (8): Wav2Vec2EncoderLayer(
#           (attention): Wav2Vec2Attention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): Wav2Vec2FeedForward(
#             (intermediate_dropout): Dropout(p=0.1, inplace=False)
#             (intermediate_dense): Linear(in_features=768, out_features=3072, bias=True)
#             (output_dense): Linear(in_features=3072, out_features=768, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (9): Wav2Vec2EncoderLayer(
#           (attention): Wav2Vec2Attention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): Wav2Vec2FeedForward(
#             (intermediate_dropout): Dropout(p=0.1, inplace=False)
#             (intermediate_dense): Linear(in_features=768, out_features=3072, bias=True)
#             (output_dense): Linear(in_features=3072, out_features=768, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (10): Wav2Vec2EncoderLayer(
#           (attention): Wav2Vec2Attention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): Wav2Vec2FeedForward(
#             (intermediate_dropout): Dropout(p=0.1, inplace=False)
#             (intermediate_dense): Linear(in_features=768, out_features=3072, bias=True)
#             (output_dense): Linear(in_features=3072, out_features=768, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#         (11): Wav2Vec2EncoderLayer(
#           (attention): Wav2Vec2Attention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.1, inplace=False)
#           (layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (feed_forward): Wav2Vec2FeedForward(
#             (intermediate_dropout): Dropout(p=0.1, inplace=False)
#             (intermediate_dense): Linear(in_features=768, out_features=3072, bias=True)
#             (output_dense): Linear(in_features=3072, out_features=768, bias=True)
#             (output_dropout): Dropout(p=0.1, inplace=False)
#           )
#           (final_layer_norm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (lm_head): Linear(in_features=768, out_features=32, bias=True)
# )

# %%
pred_strings=[]
inputs = processor1(a, sampling_rate=16_000, return_tensors="pt", padding=True)

with torch.no_grad():
    logits = model1(inputs.input_values.to("cuda")).logits

    pred_ids_en = torch.argmax(logits, dim=-1)
    pred_strings= processor1.batch_decode(pred_ids_en, skip_special_tokens=True)

# %%
" ".join(pred_strings)
# Out:
# 'thank you so much mam this is now kah tei hain ki kob surat se eqpal ka kesa bhan jata hai khub surat se epal ka kisa bhan jata hai johni kab kan zindagika hisaban jata hai kuch khast log mirte hai zindagi me hch has log milte hai zindagi me jyn se kabhina bichar ne wala rish bhnjata hai adar abhinandan abhar namaskar adab sast a cal helo in a very god evening ladies in gentleman a very very warm welcome to this absolutely wonderful beautiful and ospicious day that brings together so many special people like you i am zuhi malhotra and today i have the pleasure of being a hosters for this day ustu aj ke is program ki shuruat may karna chahungi subsay pahley ap kapret se puna ha mi wagat karna chahungi vishwaka sabsi bata raj bhasha hindi tachniky samailen mai jahpar milker iscup srut suot sabko yah kahi mahab sabko hum celebrate kahrahehai mestumi shukriya adha karna chahungi abharvak karna c ongy sre suresh kumar jendal jika joki director hai residoke ar sat hi sat mashukriya karna chahungi r ajev vijeka ganic f in mah si jinki mehnat ka nateja ajav ke samanis program ke madhyam se hum jar am me chahungi dusto shre suresh kumar jendal ji ke li zotra taliyan hojay we thank you sir for giving us this oportunity to come and present this beautiful cultural program in front of al of you thostogeter k c b shup kar re se peli hamesha hagwan ka name na anewari hota hai thovae usi khup surat si parampara kisad subsay pehliy bandana hai bhagwan sri ganesh ki sarvapratam bandana hai bhagwan shri ganesh ki ky ky n ki bajay se hai cripa varasti brama snu mahesh ki ghanesh bandana kesad aya yashu bharam karte hai aghas kartei hai s ruvat karteh ajke skhob surat shamka ghanesh wandana ae r mototin oros this oa atra ya tan te ae ts a but o aters awo ade e tehe said te tai metat a a ae pua atete an ke fromxs again is the first time ke life sabi se malakad kad eka ye moka mujha milahai may abhar vek karna chahungi aur shukriya karna chahungi ae ye age barti hue ekbahodi khub suruth sa dance up sabhi ki nazar ham pesh karne ja rahe hai there is the adesh bharat baha saray dances kuly hoa hai ar itni sada khobsr dances her p co represent kartei hai to ekbahothi kob surat she dance ki sad is celebal kuage barhati hai masti ko age ley jatei hai celebration ku barhati hai masti age le jate hai kathad ki ek khub surat re presentation up sabhi kode kate hai talia k sadus a swagat key j kata ta theuos te to sutano ana a pala hansa'

# %%
t=0.02

# %%
new=0
prev=0
x=pred_ids_en[22]
start=[]
end=[]
for i in range(len(x)):
  if x[i]!=0:
    if x[i]!=4:
      new=1
    else:
      new=2
  else:
    new=new
  if new!=prev:
    if new==2:
      end.append(i*t)
    elif new==1:
      start.append(i*t)
  prev=new

# %%
def get_start_end(x):
    new=0
    prev=0
    x=pred_ids_en[x]
    start=[]
    end=[]
    for i in range(len(x)):
      if x[i]!=0:
        if x[i]!=4:
          new=1
        else:
          new=2
      else:
        new=new
      if new!=prev:
        if new==2:
          end.append(i*t)
        elif new==1:
          start.append(i*t)
      prev=new
    if len(start)!=len(end):
      end.append(5)
    return start,end

# %%
def get_time_dict(x,k):
  
  words=pred_strings[x].split(' ')
  start,end=get_start_end(x)

  for i in range(0,len(words)):
    print('word :',words[i],'       Start_time:',(5*k+start[i]),'            end_time:',(5*k+end[i]))

# %%
for r in range(len(pred_strings)):
  k=r
  get_time_dict(r,k)
  print(r)
# Out:
# word : thank        Start_time: 0.36             end_time: 0.5
# word : you        Start_time: 0.54             end_time: 0.62
# word : so        Start_time: 0.68             end_time: 0.78
# word : much        Start_time: 0.8200000000000001             end_time: 0.96
# word : mam        Start_time: 1.02             end_time: 1.22
# word : this        Start_time: 1.78             end_time: 1.8800000000000001
# word : is        Start_time: 1.92             end_time: 1.96
# word : now        Start_time: 2.0             end_time: 2.12
# word : kah        Start_time: 2.14             end_time: 2.2600000000000002
# word : tei        Start_time: 2.3000000000000003             end_time: 2.38
# word : hain        Start_time: 2.42             end_time: 2.52
# word : ki        Start_time: 2.56             end_time: 2.68
# word : kob        Start_time: 2.72             end_time: 2.9
# word : surat        Start_time: 2.92             end_time: 3.2
# word : se        Start_time: 3.24             end_time: 3.38
# word : eqpal        Start_time: 3.44             end_time: 3.7600000000000002
# word : ka        Start_time: 3.8000000000000003             end_time: 3.94
# word : kesa        Start_time: 3.98             end_time: 4.3
# word : bhan        Start_time: 4.32             end_time: 4.48
# word : jata        Start_time: 4.5200000000000005             end_time: 4.8
# word : hai        Start_time: 4.84             end_time: 4.96
# 0
# word : khub        Start_time: 5.5600000000000005             end_time: 5.76
# word : surat        Start_time: 5.78             end_time: 6.08
# word : se        Start_time: 6.12             end_time: 6.28
# word : epal        Start_time: 6.38             end_time: 6.7
# word : ka        Start_time: 6.76             end_time: 6.88
# word : kisa        Start_time: 6.96             end_time: 7.28
# word : bhan        Start_time: 7.300000000000001             end_time: 7.46
# word : jata        Start_time: 7.5             end_time: 7.800000000000001
# word : hai        Start_time: 7.84             end_time: 8.0
# word : johni        Start_time: 8.44             end_time: 8.72
# word : kab        Start_time: 8.76             end_time: 8.94
# word : kan        Start_time: 8.98             end_time: 9.24
# word : zindagika        Start_time: 9.32             end_time: 9.940000000000001
# 1
# word : hisaban        Start_time: 10.3             end_time: 10.8
# word : jata        Start_time: 10.84             end_time: 11.16
# word : hai        Start_time: 11.2             end_time: 11.34
# word : kuch        Start_time: 11.86             end_time: 12.04
# word : khast        Start_time: 12.1             end_time: 12.379999999999999
# word : log        Start_time: 12.46             end_time: 12.66
# word : mirte        Start_time: 12.74             end_time: 13.120000000000001
# word : hai        Start_time: 13.16             end_time: 13.379999999999999
# word : zindagi        Start_time: 13.780000000000001             end_time: 14.2
# word : me        Start_time: 14.24             end_time: 14.4
# 2
# word : hch        Start_time: 15.02             end_time: 15.16
# word : has        Start_time: 15.28             end_time: 15.56
# word : log        Start_time: 15.66             end_time: 15.88
# word : milte        Start_time: 15.94             end_time: 16.32
# word : hai        Start_time: 16.38             end_time: 16.56
# word : zindagi        Start_time: 16.88             end_time: 17.28
# word : me        Start_time: 17.32             end_time: 17.5
# word : jyn        Start_time: 17.86             end_time: 18.06
# word : se        Start_time: 18.12             end_time: 18.3
# word : kabhina        Start_time: 18.36             end_time: 18.8
# word : bichar        Start_time: 18.84             end_time: 19.18
# word : ne        Start_time: 19.22             end_time: 19.32
# word : wala        Start_time: 19.36             end_time: 19.62
# word : rish        Start_time: 19.72             end_time: 19.96
# 3
# word : bhnjata        Start_time: 20.12             end_time: 20.6
# word : hai        Start_time: 20.64             end_time: 20.74
# word : adar        Start_time: 21.26             end_time: 21.64
# word : abhinandan        Start_time: 21.78             end_time: 22.28
# word : abhar        Start_time: 22.42             end_time: 22.84
# word : namaskar        Start_time: 23.5             end_time: 24.060000000000002
# word : adab        Start_time: 24.22             end_time: 24.62
# word : sast        Start_time: 24.7             end_time: 24.96
# 4
# word : a        Start_time: 25.08             end_time: 25.16
# word : cal        Start_time: 25.2             end_time: 25.5
# word : helo        Start_time: 25.8             end_time: 26.14
# word : in        Start_time: 26.22             end_time: 26.32
# word : a        Start_time: 26.38             end_time: 26.44
# word : very        Start_time: 26.5             end_time: 26.72
# word : god        Start_time: 26.76             end_time: 26.9
# word : evening        Start_time: 26.94             end_time: 27.240000000000002
# word : ladies        Start_time: 27.3             end_time: 27.56
# word : in        Start_time: 27.64             end_time: 27.7
# word : gentleman        Start_time: 27.78             end_time: 28.2
# word : a        Start_time: 28.68             end_time: 28.740000000000002
# word : very        Start_time: 28.82             end_time: 29.04
# word : very        Start_time: 29.1             end_time: 29.28
# word : warm        Start_time: 29.36             end_time: 29.560000000000002
# word : welcome        Start_time: 29.6             end_time: 29.88
# word : to        Start_time: 29.92             end_time: 29.96
# 5
# word : this        Start_time: 30.04             end_time: 30.2
# word : absolutely        Start_time: 30.3             end_time: 30.8
# word : wonderful        Start_time: 30.9             end_time: 31.36
# word : beautiful        Start_time: 31.5             end_time: 32.0
# word : and        Start_time: 32.1             end_time: 32.18
# word : ospicious        Start_time: 32.3             end_time: 32.8
# word : day        Start_time: 32.88             end_time: 33.1
# word : that        Start_time: 33.36             end_time: 33.52
# word : brings        Start_time: 33.62             end_time: 33.88
# word : together        Start_time: 33.96             end_time: 34.34
# word : so        Start_time: 34.46             end_time: 34.6
# word : many        Start_time: 34.64             end_time: 34.82
# 6
# word : special        Start_time: 35.0             end_time: 35.28
# word : people        Start_time: 35.32             end_time: 35.58
# word : like        Start_time: 35.64             end_time: 35.84
# word : you        Start_time: 35.92             end_time: 36.1
# word : i        Start_time: 36.48             end_time: 36.52
# word : am        Start_time: 36.56             end_time: 36.64
# word : zuhi        Start_time: 36.78             end_time: 37.12
# word : malhotra        Start_time: 37.14             end_time: 37.72
# word : and        Start_time: 38.08             end_time: 38.16
# word : today        Start_time: 38.24             end_time: 38.48
# word : i        Start_time: 38.68             end_time: 38.78
# word : have        Start_time: 38.82             end_time: 38.96
# word : the        Start_time: 39.0             end_time: 39.08
# word : pleasure        Start_time: 39.1             end_time: 39.42
# word : of        Start_time: 39.5             end_time: 39.58
# word : being        Start_time: 39.64             end_time: 39.84
# word : a        Start_time: 39.9             end_time: 39.92
# 7
# word : hosters        Start_time: 40.08             end_time: 40.46
# word : for        Start_time: 40.5             end_time: 40.6
# word : this        Start_time: 40.64             end_time: 40.8
# word : day        Start_time: 40.88             end_time: 41.04
# word : ustu        Start_time: 41.4             end_time: 41.72
# word : aj        Start_time: 42.06             end_time: 42.24
# word : ke        Start_time: 42.28             end_time: 42.4
# word : is        Start_time: 42.46             end_time: 42.56
# word : program        Start_time: 42.6             end_time: 43.0
# word : ki        Start_time: 43.04             end_time: 43.14
# word : shuruat        Start_time: 43.16             end_time: 43.5
# word : may        Start_time: 43.52             end_time: 43.62
# word : karna        Start_time: 43.64             end_time: 43.9
# word : chahungi        Start_time: 43.94             end_time: 44.3
# word : subsay        Start_time: 44.34             end_time: 44.64
# word : pahley        Start_time: 44.68             end_time: 44.92
# 8
# word : ap        Start_time: 45.36             end_time: 45.46
# word : kapret        Start_time: 45.5             end_time: 45.86
# word : se        Start_time: 45.92             end_time: 46.04
# word : puna        Start_time: 46.08             end_time: 46.3
# word : ha        Start_time: 46.32             end_time: 46.42
# word : mi        Start_time: 46.46             end_time: 46.58
# word : wagat        Start_time: 46.64             end_time: 46.88
# word : karna        Start_time: 46.92             end_time: 47.14
# word : chahungi        Start_time: 47.18             end_time: 47.54
# word : vishwaka        Start_time: 48.02             end_time: 48.42
# word : sabsi        Start_time: 48.46             end_time: 48.74
# word : bata        Start_time: 48.78             end_time: 48.96
# word : raj        Start_time: 49.0             end_time: 49.2
# word : bhasha        Start_time: 49.22             end_time: 49.56
# word : hindi        Start_time: 49.62             end_time: 49.92
# 9
# word : tachniky        Start_time: 50.2             end_time: 50.76
# word : samailen        Start_time: 51.04             end_time: 51.48
# word : mai        Start_time: 51.52             end_time: 51.66
# word : jahpar        Start_time: 52.0             end_time: 52.34
# word : milker        Start_time: 52.46             end_time: 52.84
# word : iscup        Start_time: 52.96             end_time: 53.28
# word : srut        Start_time: 53.32             end_time: 53.56
# word : suot        Start_time: 53.6             end_time: 53.84
# word : sabko        Start_time: 53.88             end_time: 54.22
# word : yah        Start_time: 54.28             end_time: 54.4
# word : kahi        Start_time: 54.44             end_time: 54.66
# word : mahab        Start_time: 54.7             end_time: 54.96
# 10
# word : sabko        Start_time: 55.14             end_time: 55.52
# word : hum        Start_time: 55.8             end_time: 55.98
# word : celebrate        Start_time: 56.06             end_time: 56.48
# word : kahrahehai        Start_time: 56.52             end_time: 56.98
# word : mestumi        Start_time: 57.36             end_time: 57.76
# word : shukriya        Start_time: 57.78             end_time: 58.08
# word : adha        Start_time: 58.12             end_time: 58.3
# word : karna        Start_time: 58.32             end_time: 58.58
# word : chahungi        Start_time: 58.62             end_time: 59.0
# word : abharvak        Start_time: 59.1             end_time: 59.6
# word : karna        Start_time: 59.62             end_time: 59.84
# word : c        Start_time: 59.86             end_time: 59.96
# 11
# word : ongy        Start_time: 60.06             end_time: 60.28
# word : sre        Start_time: 61.22             end_time: 61.46
# word : suresh        Start_time: 61.48             end_time: 61.82
# word : kumar        Start_time: 61.86             end_time: 62.14
# word : jendal        Start_time: 62.22             end_time: 62.5
# word : jika        Start_time: 62.54             end_time: 62.84
# word : joki        Start_time: 63.2             end_time: 63.42
# word : director        Start_time: 63.46             end_time: 63.82
# word : hai        Start_time: 63.88             end_time: 63.96
# word : residoke        Start_time: 64.0             end_time: 64.62
# 12
# word : ar        Start_time: 65.06             end_time: 65.26
# word : sat        Start_time: 66.18             end_time: 66.42
# word : hi        Start_time: 66.44             end_time: 66.56
# word : sat        Start_time: 66.6             end_time: 66.84
# word : mashukriya        Start_time: 66.88             end_time: 67.3
# word : karna        Start_time: 67.34             end_time: 67.58
# word : chahungi        Start_time: 67.64             end_time: 68.04
# word : r        Start_time: 68.68             end_time: 68.72
# word : ajev        Start_time: 68.8             end_time: 69.18
# word : vijeka        Start_time: 69.3             end_time: 69.82
# 13
# word : ganic        Start_time: 70.06             end_time: 70.36
# word : f        Start_time: 70.54             end_time: 70.6
# word : in        Start_time: 70.7             end_time: 70.78
# word : mah        Start_time: 70.82             end_time: 71.02
# word : si        Start_time: 71.06             end_time: 71.2
# word : jinki        Start_time: 71.22             end_time: 71.6
# word : mehnat        Start_time: 71.68             end_time: 71.94
# word : ka        Start_time: 71.98             end_time: 72.08
# word : nateja        Start_time: 72.12             end_time: 72.52
# word : ajav        Start_time: 72.58             end_time: 72.84
# word : ke        Start_time: 72.86             end_time: 72.98
# word : samanis        Start_time: 73.02             end_time: 73.38
# word : program        Start_time: 73.44             end_time: 73.82
# word : ke        Start_time: 73.86             end_time: 73.94
# word : madhyam        Start_time: 73.96             end_time: 74.3
# word : se        Start_time: 74.34             end_time: 74.48
# word : hum        Start_time: 74.76             end_time: 74.9
# 14
# word : jar        Start_time: 75.14             end_time: 75.32
# word : am        Start_time: 75.36             end_time: 75.42
# word : me        Start_time: 75.44             end_time: 75.54
# word : chahungi        Start_time: 75.56             end_time: 75.86
# word : dusto        Start_time: 75.9             end_time: 76.22
# word : shre        Start_time: 76.78             end_time: 76.96
# word : suresh        Start_time: 77.0             end_time: 77.28
# word : kumar        Start_time: 77.32             end_time: 77.54
# word : jendal        Start_time: 77.62             end_time: 77.9
# word : ji        Start_time: 77.94             end_time: 78.04
# word : ke        Start_time: 78.08             end_time: 78.16
# word : li        Start_time: 78.18             end_time: 78.26
# word : zotra        Start_time: 78.28             end_time: 78.58
# word : taliyan        Start_time: 78.62             end_time: 78.88
# word : hojay        Start_time: 78.9             end_time: 79.22
# 15
# word : we        Start_time: 81.48             end_time: 81.6
# word : thank        Start_time: 81.64             end_time: 81.84
# word : you        Start_time: 81.9             end_time: 81.98
# word : sir        Start_time: 82.04             end_time: 82.16
# word : for        Start_time: 82.22             end_time: 82.3
# word : giving        Start_time: 82.34             end_time: 82.54
# word : us        Start_time: 82.6             end_time: 82.68
# word : this        Start_time: 82.7             end_time: 82.82
# word : oportunity        Start_time: 82.92             end_time: 83.58
# word : to        Start_time: 83.88             end_time: 83.98
# word : come        Start_time: 84.02             end_time: 84.2
# word : and        Start_time: 84.3             end_time: 84.38
# word : present        Start_time: 84.46             end_time: 84.76
# word : this        Start_time: 84.8             end_time: 84.9
# 16
# word : beautiful        Start_time: 85.04             end_time: 85.44
# word : cultural        Start_time: 85.48             end_time: 85.84
# word : program        Start_time: 85.9             end_time: 86.34
# word : in        Start_time: 86.4             end_time: 86.46
# word : front        Start_time: 86.54             end_time: 86.72
# word : of        Start_time: 86.76             end_time: 86.82
# word : al        Start_time: 86.9             end_time: 87.0
# word : of        Start_time: 87.04             end_time: 87.12
# word : you        Start_time: 87.16             end_time: 87.24
# word : thostogeter        Start_time: 87.62             end_time: 88.18
# word : k        Start_time: 88.24             end_time: 88.3
# word : c        Start_time: 88.34             end_time: 88.44
# word : b        Start_time: 88.46             end_time: 88.62
# word : shup        Start_time: 88.64             end_time: 88.84
# word : kar        Start_time: 88.88             end_time: 89.04
# word : re        Start_time: 89.06             end_time: 89.14
# word : se        Start_time: 89.16             end_time: 89.28
# word : peli        Start_time: 89.3             end_time: 89.54
# word : hamesha        Start_time: 89.56             end_time: 89.94
# 17
# word : hagwan        Start_time: 90.02             end_time: 90.34
# word : ka        Start_time: 90.38             end_time: 90.46
# word : name        Start_time: 90.52             end_time: 90.76
# word : na        Start_time: 90.78             end_time: 90.88
# word : anewari        Start_time: 90.94             end_time: 91.36
# word : hota        Start_time: 91.4             end_time: 91.66
# word : hai        Start_time: 91.68             end_time: 91.82
# word : thovae        Start_time: 92.08             end_time: 92.48
# word : usi        Start_time: 92.76             end_time: 92.98
# word : khup        Start_time: 93.0             end_time: 93.22
# word : surat        Start_time: 93.26             end_time: 93.56
# word : si        Start_time: 93.58             end_time: 93.7
# word : parampara        Start_time: 93.72             end_time: 94.2
# word : kisad        Start_time: 94.26             end_time: 94.66
# 18
# word : subsay        Start_time: 95.02             end_time: 95.32
# word : pehliy        Start_time: 95.34             end_time: 95.58
# word : bandana        Start_time: 95.62             end_time: 95.98
# word : hai        Start_time: 96.02             end_time: 96.12
# word : bhagwan        Start_time: 96.18             end_time: 96.56
# word : sri        Start_time: 96.62             end_time: 96.84
# word : ganesh        Start_time: 96.86             end_time: 97.22
# word : ki        Start_time: 97.26             end_time: 97.44
# word : sarvapratam        Start_time: 97.98             end_time: 98.66
# word : bandana        Start_time: 98.74             end_time: 99.14
# word : hai        Start_time: 99.2             end_time: 99.36
# word : bhagwan        Start_time: 99.7             end_time: 99.96
# 19
# word : shri        Start_time: 100.16             end_time: 100.38
# word : ganesh        Start_time: 100.42             end_time: 100.8
# word : ki        Start_time: 100.84             end_time: 101.06
# word : ky        Start_time: 101.42             end_time: 101.58
# word : ky        Start_time: 101.64             end_time: 101.74
# word : n        Start_time: 101.84             end_time: 101.9
# word : ki        Start_time: 101.98             end_time: 102.12
# word : bajay        Start_time: 102.16             end_time: 102.5
# word : se        Start_time: 102.58             end_time: 102.7
# word : hai        Start_time: 102.74             end_time: 102.84
# word : cripa        Start_time: 102.88             end_time: 103.2
# word : varasti        Start_time: 103.26             end_time: 103.82
# word : brama        Start_time: 104.16             end_time: 104.64
# 20
# word : snu        Start_time: 105.08             end_time: 105.36
# word : mahesh        Start_time: 105.58             end_time: 105.94
# word : ki        Start_time: 105.98             end_time: 106.14
# word : ghanesh        Start_time: 106.4             end_time: 106.7
# word : bandana        Start_time: 106.74             end_time: 107.06
# word : kesad        Start_time: 107.12             end_time: 107.46
# word : aya        Start_time: 107.52             end_time: 107.62
# word : yashu        Start_time: 107.64             end_time: 107.9
# word : bharam        Start_time: 107.92             end_time: 108.2
# word : karte        Start_time: 108.24             end_time: 108.5
# word : hai        Start_time: 108.54             end_time: 108.64
# word : aghas        Start_time: 108.74             end_time: 109.14
# word : kartei        Start_time: 109.18             end_time: 109.44
# word : hai        Start_time: 109.48             end_time: 109.58
# word : s        Start_time: 109.86             end_time: 109.96
# 21
# word : ruvat        Start_time: 110.06             end_time: 110.34
# word : karteh        Start_time: 110.38             end_time: 110.74
# word : ajke        Start_time: 110.82             end_time: 111.14
# word : skhob        Start_time: 111.16             end_time: 111.52
# word : surat        Start_time: 111.56             end_time: 111.88
# word : shamka        Start_time: 112.12             end_time: 112.56
# word : ghanesh        Start_time: 112.82             end_time: 113.14
# word : wandana        Start_time: 113.18             end_time: 115
# 22
# word : ae        Start_time: 116.04             end_time: 116.34
# word : r        Start_time: 116.48             end_time: 116.58
# word : mototin        Start_time: 116.72             end_time: 117.52
# word : oros        Start_time: 117.62             end_time: 118.6
# 23
# word : this        Start_time: 120.3             end_time: 120.54
# word : oa        Start_time: 121.18             end_time: 121.56
# word : atra        Start_time: 121.66             end_time: 122.04
# word : ya        Start_time: 122.22             end_time: 122.4
# word : tan        Start_time: 122.44             end_time: 122.68
# word : te        Start_time: 122.84             end_time: 123.1
# word : ae        Start_time: 123.18             end_time: 123.46
# word : ts        Start_time: 123.72             end_time: 123.98
# word : a        Start_time: 124.24             end_time: 124.52
# word : but        Start_time: 124.58             end_time: 124.78
# word : o        Start_time: 124.86             end_time: 124.96
# 24
# word : aters        Start_time: 125.1             end_time: 125.4
# word : awo        Start_time: 125.5             end_time: 125.86
# word : ade        Start_time: 126.14             end_time: 126.5
# word : e        Start_time: 126.6             end_time: 126.7
# word : tehe        Start_time: 126.72             end_time: 129.24
# word : said        Start_time: 129.3             end_time: 129.52
# 25
# word : te        Start_time: 130.62             end_time: 130.32
# word : tai        Start_time: 131.04             end_time: 130.92
# word : metat        Start_time: 131.68             end_time: 131.64
# word : a        Start_time: 132.58             end_time: 132.44
# word : a        Start_time: 132.76             end_time: 132.68
# word : ae        Start_time: 133.22             end_time: 132.92
# 26
# word : pua        Start_time: 137.26             end_time: 137.62
# word : atete        Start_time: 137.72             end_time: 140
# 27
# word : an        Start_time: 144.74             end_time: 144.96
# 28
# word : ke        Start_time: 145.4             end_time: 145.64
# word : fromxs        Start_time: 146.42             end_time: 147.18
# word : again        Start_time: 147.22             end_time: 147.4
# word : is        Start_time: 147.5             end_time: 147.78
# word : the        Start_time: 147.82             end_time: 147.92
# word : first        Start_time: 147.98             end_time: 148.22
# word : time        Start_time: 148.3             end_time: 148.5
# word : ke        Start_time: 148.56             end_time: 148.68
# word : life        Start_time: 148.72             end_time: 148.96
# word : sabi        Start_time: 149.02             end_time: 149.26
# word : se        Start_time: 149.28             end_time: 149.42
# word : malakad        Start_time: 149.46             end_time: 149.82
# word : kad        Start_time: 149.84             end_time: 149.96
# 29
# word : eka        Start_time: 150.08             end_time: 150.26
# word : ye        Start_time: 150.28             end_time: 150.38
# word : moka        Start_time: 150.4             end_time: 150.66
# word : mujha        Start_time: 150.72             end_time: 150.92
# word : milahai        Start_time: 150.94             end_time: 151.28
# word : may        Start_time: 151.32             end_time: 151.42
# word : abhar        Start_time: 151.44             end_time: 151.72
# word : vek        Start_time: 151.74             end_time: 151.88
# word : karna        Start_time: 151.92             end_time: 152.16
# word : chahungi        Start_time: 152.2             end_time: 152.58
# word : aur        Start_time: 153.0             end_time: 153.1
# word : shukriya        Start_time: 153.18             end_time: 153.5
# word : karna        Start_time: 153.54             end_time: 153.78
# word : chahungi        Start_time: 153.82             end_time: 154.18
# word : ae        Start_time: 154.52             end_time: 154.62
# word : ye        Start_time: 154.64             end_time: 154.72
# word : age        Start_time: 154.76             end_time: 154.96
# 30
# word : barti        Start_time: 155.02             end_time: 155.24
# word : hue        Start_time: 155.28             end_time: 155.46
# word : ekbahodi        Start_time: 155.76             end_time: 156.22
# word : khub        Start_time: 156.26             end_time: 156.42
# word : suruth        Start_time: 156.44             end_time: 156.68
# word : sa        Start_time: 156.7             end_time: 156.78
# word : dance        Start_time: 156.82             end_time: 157.04
# word : up        Start_time: 157.12             end_time: 157.22
# word : sabhi        Start_time: 157.26             end_time: 157.46
# word : ki        Start_time: 157.5             end_time: 157.56
# word : nazar        Start_time: 157.6             end_time: 157.78
# word : ham        Start_time: 157.8             end_time: 157.9
# word : pesh        Start_time: 157.92             end_time: 158.12
# word : karne        Start_time: 158.14             end_time: 158.38
# word : ja        Start_time: 158.42             end_time: 158.54
# word : rahe        Start_time: 158.56             end_time: 158.74
# word : hai        Start_time: 158.8             end_time: 158.9
# word : there        Start_time: 159.18             end_time: 159.3
# word : is        Start_time: 159.32             end_time: 159.4
# word : the        Start_time: 159.44             end_time: 159.56
# 31
# word : adesh        Start_time: 160.1             end_time: 160.36
# word : bharat        Start_time: 160.4             end_time: 160.72
# word : baha        Start_time: 161.3             end_time: 161.54
# word : saray        Start_time: 161.58             end_time: 161.8
# word : dances        Start_time: 161.88             end_time: 162.28
# word : kuly        Start_time: 162.34             end_time: 162.62
# word : hoa        Start_time: 162.66             end_time: 162.84
# word : hai        Start_time: 162.88             end_time: 163.02
# word : ar        Start_time: 163.14             end_time: 163.22
# word : itni        Start_time: 163.34             end_time: 163.58
# word : sada        Start_time: 163.62             end_time: 163.86
# word : khobsr        Start_time: 163.88             end_time: 164.26
# word : dances        Start_time: 164.28             end_time: 164.6
# word : her        Start_time: 164.66             end_time: 164.76
# word : p        Start_time: 164.8             end_time: 164.96
# 32
# word : co        Start_time: 165.18             end_time: 165.34
# word : represent        Start_time: 166.02             end_time: 166.42
# word : kartei        Start_time: 166.46             end_time: 166.72
# word : hai        Start_time: 166.76             end_time: 166.88
# word : to        Start_time: 167.14             end_time: 167.5
# word : ekbahothi        Start_time: 167.58             end_time: 168.06
# word : kob        Start_time: 168.1             end_time: 168.28
# word : surat        Start_time: 168.3             end_time: 168.6
# word : she        Start_time: 168.64             end_time: 168.76
# word : dance        Start_time: 168.8             end_time: 169.06
# word : ki        Start_time: 169.1             end_time: 169.24
# word : sad        Start_time: 169.28             end_time: 169.52
# word : is        Start_time: 169.6             end_time: 169.66
# word : celebal        Start_time: 169.7             end_time: 169.96
# 33
# word : kuage        Start_time: 170.26             end_time: 170.58
# word : barhati        Start_time: 170.62             end_time: 171.0
# word : hai        Start_time: 171.04             end_time: 171.14
# word : masti        Start_time: 171.28             end_time: 171.64
# word : ko        Start_time: 171.68             end_time: 171.78
# word : age        Start_time: 171.86             end_time: 172.08
# word : ley        Start_time: 172.12             end_time: 172.24
# word : jatei        Start_time: 172.28             end_time: 172.54
# word : hai        Start_time: 172.58             end_time: 172.68
# word : celebration        Start_time: 173.18             end_time: 173.68
# word : ku        Start_time: 173.74             end_time: 173.86
# word : barhati        Start_time: 173.88             end_time: 174.3
# word : hai        Start_time: 174.34             end_time: 174.44
# word : masti        Start_time: 174.58             end_time: 174.9
# 34
# word : age        Start_time: 175.08             end_time: 175.28
# word : le        Start_time: 175.3             end_time: 175.42
# word : jate        Start_time: 175.46             end_time: 175.72
# word : hai        Start_time: 175.76             end_time: 175.88
# word : kathad        Start_time: 176.26             end_time: 176.6
# word : ki        Start_time: 176.68             end_time: 176.8
# word : ek        Start_time: 176.86             end_time: 176.98
# word : khub        Start_time: 177.04             end_time: 177.2
# word : surat        Start_time: 177.24             end_time: 177.48
# word : re        Start_time: 177.52             end_time: 177.62
# word : presentation        Start_time: 177.64             end_time: 178.2
# word : up        Start_time: 178.3             end_time: 178.42
# word : sabhi        Start_time: 178.48             end_time: 178.7
# word : kode        Start_time: 178.74             end_time: 178.96
# word : kate        Start_time: 178.98             end_time: 179.24
# word : hai        Start_time: 179.26             end_time: 179.36
# word : talia        Start_time: 179.7             end_time: 179.96
# 35
# word : k        Start_time: 180.06             end_time: 180.12
# word : sadus        Start_time: 180.14             end_time: 180.44
# word : a        Start_time: 180.5             end_time: 180.56
# word : swagat        Start_time: 180.58             end_time: 180.9
# word : key        Start_time: 180.94             end_time: 181.04
# word : j        Start_time: 181.1             end_time: 181.24
# word : kata        Start_time: 181.62             end_time: 185
# 36
# word : ta        Start_time: 188.6             end_time: 189.96
# 37
# word : theuos        Start_time: 190.18             end_time: 193.02
# word : te        Start_time: 193.86             end_time: 194.22
# word : to        Start_time: 194.64             end_time: 194.96
# 38
# word : sutano        Start_time: 196.2             end_time: 199.92
# 39
# word : ana        Start_time: 201.06             end_time: 201.78
# word : a        Start_time: 202.4             end_time: 202.6
# word : pala        Start_time: 202.82             end_time: 203.2
# word : hansa        Start_time: 203.26             end_time: 203.76
# 40
